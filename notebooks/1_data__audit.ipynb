# %% [markdown]
# <a href="https://colab.research.google.com/github/pravallikai/Evolution-of-musical-trends-using-py/blob/main/notebooks/1_data__audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Colab: connect to your GitHub repo so we can see files ---
import os, sys, pathlib

# CHANGE these two lines to YOUR username and repo name:
GITHUB_USER = "pravallikai"            # <- your GitHub username
REPO_NAME   = "Evolution-of-musical-trends-using-py"  # <- your repo name exactly

if not pathlib.Path(REPO_NAME).exists():
    # !git clone https://github.com/{GITHUB_USER}/{REPO_NAME}.git

os.chdir(REPO_NAME)

# let Python import from src/
if "src" not in sys.path:
    sys.path.append("src")

print("Here now:", os.getcwd())
print("Top-level files/folders:", os.listdir())
# Out:
# Cloning into 'Evolution-of-musical-trends-using-py'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 38 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 10.25 KiB | 2.56 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Here now: /content/Evolution-of-musical-trends-using-py/Evolution-of-musical-trends-using-py
# Top-level files/folders: ['notebooks', 'data', 'README.md', '.gitignore', 'src', 'reports', '.git']

# %%
import pandas as pd
from src.io_utils import read_csv

df = read_csv("mini_tracks.csv")
df.head()      # shows first 5 rows
# Out:
#   track_name artist_name  year    genre  danceability  energy  tempo  valence  \
# 0     Song A    Artist X  1985     rock          0.55    0.72    110     0.40
# 1     Song B    Artist Y  1995      pop          0.70    0.65     98     0.60
# 2     Song C    Artist Z  2005  hip-hop          0.80    0.75     92     0.55
# 3     Song D    Artist Q  2015      edm          0.60    0.85    128     0.65
# 4     Song E    Artist W  2020    indie          0.65    0.55    105     0.50
#
#    loudness  duration_ms
# 0      -7.0       210000
# 1      -6.5       195000
# 2      -5.0       230000
# 3      -4.5       180000
# 4      -8.0       240000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    5 non-null      object
#  1   artist_name   5 non-null      object
#  2   year          5 non-null      int64
#  3   genre         5 non-null      object
#  4   danceability  5 non-null      float64
#  5   energy        5 non-null      float64
#  6   tempo         5 non-null      int64
#  7   valence       5 non-null      float64
#  8   loudness      5 non-null      float64
#  9   duration_ms   5 non-null      int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe(include="all")
# Out:
#        track_name artist_name         year genre  danceability    energy  \
# count           5           5     5.000000     5      5.000000  5.000000
# unique          5           5          NaN     5           NaN       NaN
# top        Song A    Artist X          NaN  rock           NaN       NaN
# freq            1           1          NaN     1           NaN       NaN
# mean          NaN         NaN  2004.000000   NaN      0.660000  0.704000
# std           NaN         NaN    14.317821   NaN      0.096177  0.112161
# min           NaN         NaN  1985.000000   NaN      0.550000  0.550000
# 25%           NaN         NaN  1995.000000   NaN      0.600000  0.650000
# 50%           NaN         NaN  2005.000000   NaN      0.650000  0.720000
# 75%           NaN         NaN  2015.000000   NaN      0.700000  0.750000
# max           NaN         NaN  2020.000000   NaN      0.800000  0.850000
#
#              tempo   valence  loudness    duration_ms
# ...

# %%
# % missing per column
(df.isna().mean()*100).sort_values(ascending=False)

# duplicates by (track_name, artist_name, year)
dupes = df.duplicated(subset=["track_name","artist_name","year"])
dupes.sum()
# Out:
# np.int64(0)
